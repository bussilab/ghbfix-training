# %%
#this notebook visualizes all favoring interaction in gHBfix_opt
#ultimately the results published in this study are obtained

# %%
import py3Dmol
import numpy as np
import matplotlib.pyplot as plt

# %%
def reorder(input_array):
    
    temp=input_array
    
    input_array=np.array([temp[1],temp[4],temp[3],temp[5],temp[0],temp[2],temp[7],temp[10],temp[9],temp[11],temp[6],temp[8]])
    
    return input_array

# %%
error= np.load('./data_produced/chi2.npy',allow_pickle=True)
lambdas = np.load('./data_produced/parameters.npy',allow_pickle=True)

gHBfix=[]
for i in range(12):
    gHBfix.append(0.0)

gHBfix[1]=1.0
gHBfix[6]=-0.5
gHBfix[8]=-0.5
gHBfix=np.array(gHBfix)   
data=lambdas /1.666666666666666
data=data+gHBfix
cmap = plt.cm.get_cmap('gist_gray')

for l,lambdas in enumerate(data):
    newlambdas = reorder(data[l]).reshape(-1,12)
    l=newlambdas[0].reshape(2,6)
    plt.matshow(l,cmap='seismic_r',vmin=-0.5,vmax=0.5)
    for (i, j), z in np.ndenumerate(l):
        c='white' 
        plt.text(j, i, '{:0.1f}'.format(z), ha='center', va='center', fontsize=23, color=c)
    plt.axis('off')
    plt.show()

# %%
#interaction NH-Nbase
pdb_e = open('./data_loaded/UUCG_native.pdb','r').read()
p = py3Dmol.view(width=900,height=600)
p.addModel(pdb_e,'pdb',{'keepH': True})

p.setStyle({'stick': {'color':'lightgrey'}}) 

p.setStyle({'resi': ["1","7"],'atom': ["H1"]},{'sphere': {'color':'blue','scale':'0.5'}}) 
p.setStyle({'resi': ["1","6"],'atom': ["H22"]},{'sphere': {'color':'blue','scale':'0.5'}}) 
p.setStyle({'resi': ["3"],'atom': ["H3"]},{'sphere': {'color':'blue','scale':'0.5'}}) 

#acceptors
p.setStyle({'resi': ["2","5","8"],'atom': ["N3"]},{'sphere': {'color':'red','scale':'0.5'}}) 
p.setStyle({'resi': ["7"],'atom': ["N7"]},{'sphere': {'color':'red','scale':'0.5'}}) 
 

p.zoomTo()
# Out:
# <div id="3dmolviewer_16410987107076309"  style="position: relative; width: 900px; height: 600px">
#         <p id="3dmolwarning_16410987107076309" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16410987107076309 = null;
# var warn = document.getElementById("3dmolwarning_16410987107076309");
0.00           O  \nATOM     35  O2P  C      2       4.045  -9.499  -0.817  1.00  0.00           O  \nATOM     36  O5'  C      2       4.763  -8.450   1.331  1.00  0.00           O  \nATOM     37  C5'  C      2       5.163  -8.365   2.692  1.00  0.00           C  \nATOM     38 H5'1  C      2       6.199  -8.671   2.839  1.00  0.00           H  \nATOM     39 H5'2  C      2       4.527  -9.081   3.212  1.00  0.00           H  \nATOM     40  C4'  C      2       5.053  -6.962   3.187  1.00  0.00           C  \nATOM     41  H4'  C      2       5.248  -7.039   4.257  1.00  0.00           H  \nATOM     42  O4'  C      2       5.859  -6.003   2.497  1.00  0.00           O  \nATOM     43  C1'  C      2       5.174  -4.747   2.283  1.00  0.00           C  \nATOM     44  H1'  C      2       5.804  -3.906   2.572  1.00  0.00           H  \nATOM     45  N1   C      2       4.819  -4.609   0.837  1.00  0.00           N  \nATOM     46  C6   C      2       4.809  -5.643  -0.098  1.00  0.00           C  \nATOM     47  H6   C      2       5.062  -6.666   0.140  1.00  0.00           H  \nATOM     48  C5   C      2       4.517  -5.341  -1.433  1.00  0.00           C  \nATOM     49  H5   C  ...

# %%
#interaction NH-Obase
pdb_e = open('./data_loaded/UUCG_native.pdb','r').read()
p = py3Dmol.view(width=900,height=600)
p.addModel(pdb_e,'pdb',{'keepH': True})

p.setStyle({'stick': {'color':'lightgrey'}}) 

p.setStyle({'resi': ["2","8"],'atom': ["H41","H42"]},{'sphere': {'color':'blue','scale':'0.5'}}) 
p.setStyle({'resi': ["1","7"],'atom': ["H22"]},{'sphere': {'color':'blue','scale':'0.5'}}) 
p.setStyle({'resi': ["6"],'atom': ["H1"]},{'sphere': {'color':'blue','scale':'0.5'}}) 

p.setStyle({'resi': ["3","2","8"],'atom': ["O2"]},{'sphere': {'color':'red','scale':'0.5'}}) 
p.setStyle({'resi': ["1","7"],'atom': ["O6"]},{'sphere': {'color':'red','scale':'0.5'}}) 

p.zoomTo()
# Out:
# <div id="3dmolviewer_164109871072663"  style="position: relative; width: 900px; height: 600px">
#         <p id="3dmolwarning_164109871072663" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_164109871072663 = null;
# var warn = document.getElementById("3dmolwarning_164109871072663");
# if(warn) {
#     warn.parentNode.removeChild(warn);
4.045  -9.499  -0.817  1.00  0.00           O  \nATOM     36  O5'  C      2       4.763  -8.450   1.331  1.00  0.00           O  \nATOM     37  C5'  C      2       5.163  -8.365   2.692  1.00  0.00           C  \nATOM     38 H5'1  C      2       6.199  -8.671   2.839  1.00  0.00           H  \nATOM     39 H5'2  C      2       4.527  -9.081   3.212  1.00  0.00           H  \nATOM     40  C4'  C      2       5.053  -6.962   3.187  1.00  0.00           C  \nATOM     41  H4'  C      2       5.248  -7.039   4.257  1.00  0.00           H  \nATOM     42  O4'  C      2       5.859  -6.003   2.497  1.00  0.00           O  \nATOM     43  C1'  C      2       5.174  -4.747   2.283  1.00  0.00           C  \nATOM     44  H1'  C      2       5.804  -3.906   2.572  1.00  0.00           H  \nATOM     45  N1   C      2       4.819  -4.609   0.837  1.00  0.00           N  \nATOM     46  C6   C      2       4.809  -5.643  -0.098  1.00  0.00           C  \nATOM     47  H6   C      2       5.062  -6.666   0.140  1.00  0.00           H  \nATOM     48  C5   C      2       4.517  -5.341  -1.433  1.00  0.00           C  \nATOM     49  H5   C    ...

# %%
#interaction 3 NH-nbO
pdb_e = open('./data_loaded/UUCG_native.pdb','r').read()
p = py3Dmol.view(width=900,height=600)
p.addModel(pdb_e,'pdb',{'keepH': True})

p.setStyle({'stick': {'color':'lightgrey'}})


p.setStyle({'resi': ["5"],'atom': ["H41","H42"]},{'sphere': {'color':'blue','scale':'0.5'}}) 

p.setStyle({'resi': ["4"],'atom':["O2P"]},{'sphere': {'color':'red','scale':'0.5'}}) 

p.zoomTo()
# Out:
# <div id="3dmolviewer_16410987107413714"  style="position: relative; width: 900px; height: 600px">
#         <p id="3dmolwarning_16410987107413714" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16410987107413714 = null;
# var warn = document.getElementById("3dmolwarning_16410987107413714");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16410987107413714 = $3Dmol.createViewer($("#3dmolviewer_16410987107413714"),{backgroundColor:"white"});
# viewer_16410987107413714.zoomTo();
ATOM     40  C4'  C      2       5.053  -6.962   3.187  1.00  0.00           C  \nATOM     41  H4'  C      2       5.248  -7.039   4.257  1.00  0.00           H  \nATOM     42  O4'  C      2       5.859  -6.003   2.497  1.00  0.00           O  \nATOM     43  C1'  C      2       5.174  -4.747   2.283  1.00  0.00           C  \nATOM     44  H1'  C      2       5.804  -3.906   2.572  1.00  0.00           H  \nATOM     45  N1   C      2       4.819  -4.609   0.837  1.00  0.00           N  \nATOM     46  C6   C      2       4.809  -5.643  -0.098  1.00  0.00           C  \nATOM     47  H6   C      2       5.062  -6.666   0.140  1.00  0.00           H  \nATOM     48  C5   C      2       4.517  -5.341  -1.433  1.00  0.00           C  \nATOM     49  H5   C  ...

# %%
#interaction 8 OH-Nbase
pdb_e = open('./data_loaded/UUCG_native.pdb','r').read()
p = py3Dmol.view(width=900,height=600)
p.addModel(pdb_e,'pdb',{'keepH': True})

    
p.setStyle({'stick': {'color':'lightgrey'}}) 

p.setStyle({'resi': ["6"],'atom': ["N7"]},{'sphere': {'color':'red','scale':'0.5'}}) 
p.setStyle({'resi': ["4"],'atom': ["HO'2"]},{'sphere': {'color':'blue','scale':'0.5'}})

p.zoomTo()
# Out:
# <div id="3dmolviewer_16410987107559588"  style="position: relative; width: 900px; height: 600px">
#         <p id="3dmolwarning_16410987107559588" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16410987107559588 = null;
# var warn = document.getElementById("3dmolwarning_16410987107559588");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16410987107559588 = $3Dmol.createViewer($("#3dmolviewer_16410987107559588"),{backgroundColor:"white"});
# viewer_16410987107559588.zoomTo();
# 	viewer_16410987107559588.addModel("REMARK\nATOM      1  H5T G       1       7.465 -10.934  -4.220  1.00  0.00           H  \nATOM      2  O5' G       1       7.008 -10.590  -3.450  1.00  0.00           O  \nATOM      3  C5' G       1       7.429 -11.264  -2.191  1.00  0.00           C  \nATOM      4 H5'1 G       1       8.028 -12.150  -2.404  1.00  0.00           H  \nATOM      5 H5'2 G       1       6.523 -11.624  -1.703  1.00  0.00           H  \nATOM      6  C4' G       1       8.042 -10.316  -1.172  1.00  0.00           C  \nATOM      
# %%
#interaction 11 OH-Obase
pdb_e = open('./data_loaded/UUCG_native.pdb','r').read()
p = py3Dmol.view(width=900,height=600)
p.addModel(pdb_e,'pdb',{'keepH': True})

p.setStyle({'stick': {'color':'lightgrey'}}) 

    
p.setStyle({'resi': ["6"],'atom': ["O6"]},{'sphere': {'color':'red','scale':'0.5'}}) 
p.setStyle({'resi': ["3","4"],'atom': ["HO'2"]},{'sphere': {'color':'blue','scale':'0.5'}})

p.zoomTo()
# Out:
# <div id="3dmolviewer_16410987107706223"  style="position: relative; width: 900px; height: 600px">
#         <p id="3dmolwarning_16410987107706223" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16410987107706223 = null;
# var warn = document.getElementById("3dmolwarning_16410987107706223");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16410987107706223 = $3Dmol.createViewer($("#3dmolviewer_16410987107706223"),{backgroundColor:"white"});
# viewer_16410987107706223.zoomTo();
# 	viewer_16410987107706223.addModel("REMARK\nATOM      1  H5T G       1       7.465 -10.934  -4.220  1.00  0.00           H  \nATOM      2  O5' G       1       7.008 -10.590  -3.450  1.00  0.00           O  \nATOM      3  C5' G       1       7.429 -11.264  -2.191  1.00  0.00           C  \nATOM      4 H5'1 G       1       8.028 -12.150  -2.404  1.00  0.00           H  \nATOM      5 H5'2 G       1       6.523 -11.624  -1.703  1.00  0.00           H  \nATOM      6  C4' G       1       8.042 -10.316  -1.172  1.00  0.00           C  \nATOM      7  H4' G       1       8.573 -10.909  -0.428  1.00  0.00           H  \nATOM      8  O4' G       1       8.925  -9.352  -1.737  1.00  0.00           O  \nATOM      9  C1' G       1       8.771  -8.105  -0.985  1.00  0.00           C  \nATOM     10  H1' G       1       9.651  -7.701  -0.485  1.00  0.00           H  \nATOM     11  N9  G       1       8.282  -7.139  -1.954  1.