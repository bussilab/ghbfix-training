# %%
#this notebook visualizes all favoring interaction in gHBfix_opt
#ultimately the results published in this study are obtained

# %%
import py3Dmol
import numpy as np
import matplotlib.pyplot as plt

# %%
def reorder(input_array):
    
    temp=input_array
    
    input_array=np.array([temp[1],temp[4],temp[3],temp[5],temp[0],temp[2],temp[7],temp[10],temp[9],temp[11],temp[6],temp[8]])
    
    return input_array

# %%
error= np.load('./data_produced/chi2.npy',allow_pickle=True)
lambdas = np.load('./data_produced/parameters.npy',allow_pickle=True)

gHBfix=[]
for i in range(12):
    gHBfix.append(0.0)

gHBfix[1]=1.0
gHBfix[6]=-0.5
gHBfix[8]=-0.5
gHBfix=np.array(gHBfix)   
data=lambdas /1.666666666666666
data=data+gHBfix
cmap = plt.cm.get_cmap('gist_gray')

for l,lambdas in enumerate(data):
    newlambdas = reorder(data[l]).reshape(-1,12)
    l=newlambdas[0].reshape(2,6)
    plt.matshow(l,cmap='seismic_r',vmin=np.min(l),vmax=np.max(l))
    for (i, j), z in np.ndenumerate(l):
        c='white' 
        plt.text(j, i, '{:0.1f}'.format(z), ha='center', va='center', fontsize=23, color=c)
    plt.axis('off')
    plt.show()

# %%
#interaction NH-N
pdb_e = open('./data_loaded/UUCG_native.pdb','r').read()
p = py3Dmol.view(width=900,height=600)
p.addModel(pdb_e,'pdb')

p.setStyle({'stick': {'color':'lightgrey'}}) 


p.setStyle({'resi': ["1","7","6"],'atom': ["N1"]},{'sphere': {'color':'blue','scale':'0.5'}}) 
p.setStyle({'resi': ["1","7"],'atom': ["N2"]},{'sphere': {'color':'blue','scale':'0.5'}}) 
p.setStyle({'resi': ["3"],'atom': ["N3"]},{'sphere': {'color':'blue','scale':'0.5'}}) 
p.setStyle({'resi': ["2","5","8"],'atom': ["N4"]},{'sphere': {'color':'blue','scale':'0.5'}}) 


p.setStyle({'resi': ["2","5","8"],'atom': ["N3"]},{'sphere': {'color':'red','scale':'0.5'}}) 
p.setStyle({'resi': ["6","7"],'atom': ["N7"]},{'sphere': {'color':'red','scale':'0.5'}}) 
 

p.zoomTo()
# Out:
# <div id="3dmolviewer_16353582271983163"  style="position: relative; width: 900px; height: 600px">
#         <p id="3dmolwarning_16353582271983163" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# ...

# %%
#interaction NH-Obase
pdb_e = open('./data_loaded/UUCG_native.pdb','r').read()
p = py3Dmol.view(width=900,height=600)
p.addModel(pdb_e,'pdb')

p.setStyle({'stick': {'color':'lightgrey'}}) 

p.setStyle({'resi': ["7","1"],'atom': ["N2"]},{'sphere': {'color':'blue','scale':'0.5'}})
p.setStyle({'resi': ["2","8"],'atom': ["N4"]},{'sphere': {'color':'blue','scale':'0.5'}}) 
p.setStyle({'resi': ["6"],'atom': ["N1"]},{'sphere': {'color':'blue','scale':'0.5'}}) 
p.setStyle({'resi': ["3"],'atom': ["N3"]},{'sphere': {'color':'blue','scale':'0.5'}}) 

p.setStyle({'resi': ["3","2","8"],'atom': ["O2"]},{'sphere': {'color':'red','scale':'0.5'}}) 
p.setStyle({'resi': ["1","7"],'atom': ["O6"]},{'sphere': {'color':'red','scale':'0.5'}}) 

p.zoomTo()
# Out:
# <div id="3dmolviewer_1635358234196816"  style="position: relative; width: 900px; height: 600px">
#         <p id="3dmolwarning_1635358234196816" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_1635358234196816 = null;
# ...

# %%
#interaction 3 NH-nbO
pdb_e = open('./data_loaded/UUCG_native.pdb','r').read()
p = py3Dmol.view(width=900,height=600)
p.addModel(pdb_e,'pdb')

p.setStyle({'stick': {'color':'lightgrey'}})

p.setStyle({'resi': ["4"],'atom':["O2P"]},{'sphere': {'color':'red','scale':'0.5'}}) 
p.setStyle({'resi': ["5"],'atom': ["N4"]},{'sphere': {'color':'blue','scale':'0.5'}}) 

p.zoomTo()
# Out:
# <div id="3dmolviewer_16353582373762891"  style="position: relative; width: 900px; height: 600px">
#         <p id="3dmolwarning_16353582373762891" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# ...

# %%
#interaction 8 OH-Nbase
pdb_e = open('./data_loaded/UUCG_native.pdb','r').read()
p = py3Dmol.view(width=900,height=600)
p.addModel(pdb_e,'pdb')

p.setStyle({'stick': {'color':'lightgrey'}}) 

p.setStyle({'resi': ["6"],'atom': ["N7"]},{'sphere': {'color':'red','scale':'0.5'}}) 
p.setStyle({'resi': ["4"],'atom': ["O2'"]},{'sphere': {'color':'blue','scale':'0.5'}})

p.zoomTo()
# Out:
# <div id="3dmolviewer_163535824118379"  style="position: relative; width: 900px; height: 600px">
#         <p id="3dmolwarning_163535824118379" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_163535824118379 = null;
# ...

# %%
#interaction 11 OH-Obase
pdb_e = open('./data_loaded/UUCG_native.pdb','r').read()
p = py3Dmol.view(width=900,height=600)
p.addModel(pdb_e,'pdb')

p.setStyle({'stick': {'color':'lightgrey'}}) 

p.setStyle({'resi': ["6"],'atom': ["O6"]},{'sphere': {'color':'red','scale':'0.5'}}) 
p.setStyle({'resi': ["3"],'atom': ["O2'"]},{'sphere': {'color':'blue','scale':'0.5'}})
p.setStyle({'resi': ["4"],'atom': ["O2'"]},{'sphere': {'color':'blue','scale':'0.5'}}) 

p.zoomTo()
# Out:
# <div id="3dmolviewer_1635358246815531"  style="position: relative; width: 900px; height: 600px">
#         <p id="3dmolwarning_1635358246815531" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_1635358246815531 = null;
# ...
